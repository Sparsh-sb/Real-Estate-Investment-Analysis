# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv("../data/processed/gurgaon_10k_summary.csv")

# %%
df.head()
# Out:
#      PROP_ID                                          PHOTO_URL  \
# 0  O71585872  https://mediacdn.99acres.com/media1/22409/13/4...
# 1  T71585466  https://mediacdn.99acres.com/media1/22425/6/44...
# 2  D71549524  https://mediacdn.99acres.com/media1/22386/13/4...
# 3  I71493958  https://mediacdn.99acres.com/media1/22353/14/4...
# 4  H71479412  https://mediacdn.99acres.com/media1/22352/4/44...
#
#                                     MEDIUM_PHOTO_URL PREFERENCE  \
# 0  https://mediacdn.99acres.com/media1/22409/13/4...          S
# 1  https://mediacdn.99acres.com/media1/22425/6/44...          S
# 2  https://mediacdn.99acres.com/media1/22386/13/4...          R
# 3  https://mediacdn.99acres.com/media1/22353/14/4...          S
# 4  https://mediacdn.99acres.com/media1/22352/4/44...          R
#
#                                          DESCRIPTION          PROPERTY_TYPE  \
# 0    4 bhk flat for resale in alpha corp gurgaon one  Residential Apartment
# 1  Explore dlf ultima, an upscale ready-To-Move h...  Residential Apartment
# 2  A 3 bhk flat for rent in sector 66 gurgaon clo...  Residential Apartment
# 3  Looking for a 3 bhk property for purchase in g...  Residential Apartment
# 4  This 4 bhk flat in sector 104 gurgaon is avail...  Residential Apartment
#
#       CITY            LOCALITY  TRANSACT_TYPE   OWNTYPE  ...  \
# 0  Gurgaon   Sector 84 Gurgaon            1.0  Freehold  ...
# 1  Gurgaon   Sector 81 Gurgaon            1.0  Freehold  ...
# 2  Gurgaon   Sector 66 Gurgaon            NaN       NaN  ...
# 3  Gurgaon  Sector 112 Gurgaon            1.0  Freehold  ...
# 4  Gurgaon  Sector 104 Gurgaon            NaN       NaN  ...
#
#                                             metadata  \
# 0  {'PROP_PHOTO_COUNT': '4', 'PROP_VIDEO_COUNT': ...
# 1  {'PROP_PHOTO_COUNT': '4', 'PROP_VIDEO_COUNT': ...
# 2  {'PROP_PHOTO_COUNT': '1', 'PROP_VIDEO_COUNT': ...
# 3  {'PROP_PHOTO_COUNT': '1', 'PROP_VIDEO_COUNT': ...
# 4  {'PROP_PHOTO_COUNT': '14', 'PROP_VIDEO_COUNT':...
#
#                                             location  BUILTUP_SQFT  \
# 0  {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDIN...           NaN
# 1  {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDIN...           NaN
# 2  {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDIN...       1920.00
# 3  {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDIN...       2225.56
# 4  {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDIN...           NaN
#
#    SUPER_SQFT  COMMON_FURNISHING_ATTRIBUTES QUALITY_SCORE  \
# 0         NaN                           NaN           NaN
# 1         NaN                           NaN           NaN
# 2         NaN                           NaN           NaN
# 3         NaN                           NaN           NaN
# 4         NaN                           NaN           NaN
#
#   FURNISHING_ATTRIBUTES PRICE_CLEANED AREA_CLEANED PRICE_PER_SQFT
# 0                   NaN    26300000.0       3434.0    7658.707047
# 1                   NaN    36000000.0       2870.0   12543.554007
# 2                   NaN       85000.0       1950.0      43.589744
# 3                   NaN    38500000.0       2802.0   13740.185582
# 4                   NaN       40000.0       2290.0      17.467249
#
# [5 rows x 70 columns]

# %%
df.shape
# Out:
# (6695, 70)

# %%
df.columns
# Out:
# Index(['PROP_ID', 'PHOTO_URL', 'MEDIUM_PHOTO_URL', 'PREFERENCE', 'DESCRIPTION',
#        'PROPERTY_TYPE', 'CITY', 'LOCALITY', 'TRANSACT_TYPE', 'OWNTYPE',
#        'BEDROOM_NUM', 'BATHROOM_NUM', 'BALCONY_NUM', 'PRICE_PER_UNIT_AREA',
#        'FURNISH', 'FACING', 'AGE', 'FLOOR_NUM', 'TOTAL_FLOOR', 'FEATURES',
#        'REGISTER_DATE', 'PROP_NAME', 'MIN_PRICE', 'MAX_PRICE', 'PRICE_SQFT',
#        'LISTING', 'BUILDING_ID', 'CARPET_SQFT', 'SUPERBUILTUP_SQFT',
#        'BROKERAGE', 'MAP_DETAILS', 'FSL_Data', 'MIN_AREA_SQFT',
#        'MAX_AREA_SQFT', 'FORMATTED', 'AMENITIES', 'TOP_USPS', 'PD_URL',
#        'EXPIRY_DATE', 'GROUP_NAME', 'AREA', 'PRICE', 'PROP_HEADING',
#        'PROP_DETAILS_URL', 'CLASS_HEADING', 'CLASS_LABEL', 'SECONDARY_TAGS',
#        'PROPERTY_IMAGES', 'THUMBNAIL_IMAGES', 'TOTAL_LANDMARK_COUNT',
#        'FORMATTED_LANDMARK_DETAILS', 'CONTACT_NAME', 'CONTACT_COMPANY_NAME',
#        'DEALER_PHOTO_URL', 'SOCIETY_NAME', 'BUILDING_NAME', 'CITY_ID',
#        'LOCALITY_WO_CITY', 'profile', 'xid', 'metadata', 'location',
#        'BUILTUP_SQFT', 'SUPER_SQFT', 'COMMON_FURNISHING_ATTRIBUTES',
#        'QUALITY_SCORE', 'FURNISHING_ATTRIBUTES', 'PRICE_CLEANED',
#        'AREA_CLEANED', 'PRICE_PER_SQFT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PROP_ID                   object
# PHOTO_URL                 object
# MEDIUM_PHOTO_URL          object
# PREFERENCE                object
# DESCRIPTION               object
#                           ...
# QUALITY_SCORE            float64
# FURNISHING_ATTRIBUTES    float64
# PRICE_CLEANED            float64
# AREA_CLEANED             float64
# PRICE_PER_SQFT           float64
# Length: 70, dtype: object

# %%
missing = df.isna().sum().sort_values(ascending=False)
print(missing[missing > 0])
# Out:
# QUALITY_SCORE                   6695
# FURNISHING_ATTRIBUTES           6695
# SUPER_SQFT                      6695
# COMMON_FURNISHING_ATTRIBUTES    6695
# BUILTUP_SQFT                    4547
# FLOOR_NUM                       4086
# CARPET_SQFT                     3046
# TOP_USPS                        1468
# MEDIUM_PHOTO_URL                1107
# PHOTO_URL                       1107
# THUMBNAIL_IMAGES                1106
# PROPERTY_IMAGES                 1106
# FACING                           578
# OWNTYPE                          334
# TRANSACT_TYPE                    334
# SOCIETY_NAME                     326
# PROP_NAME                        326
# BUILDING_NAME                    326
# TOTAL_FLOOR                      126
# BATHROOM_NUM                     104
# BROKERAGE                         38
# CONTACT_NAME                      31
# TOTAL_LANDMARK_COUNT              25
# FORMATTED_LANDMARK_DETAILS        25
# AMENITIES                          9
# BALCONY_NUM                        7
# BEDROOM_NUM                        6
# CONTACT_COMPANY_NAME               1
# dtype: int64

# %%
df.describe(include='all').T
# Out:
#                         count unique  \
# PROP_ID                  6695   6695
# PHOTO_URL                5588   5575
# MEDIUM_PHOTO_URL         5588   5575
# PREFERENCE               6695      2
# DESCRIPTION              6695   6144
# ...                       ...    ...
# QUALITY_SCORE             0.0    NaN
# FURNISHING_ATTRIBUTES     0.0    NaN
# PRICE_CLEANED          6695.0    NaN
# AREA_CLEANED           6695.0    NaN
# PRICE_PER_SQFT         6695.0    NaN
#
#                                                                      top  \
# PROP_ID                                                        C71777090
# PHOTO_URL              https://static.99acres.com/images/under_screen...
# MEDIUM_PHOTO_URL       https://static.99acres.com/images/under_screen...
# PREFERENCE                                                             S
# DESCRIPTION            Very nicely built up ultra luxury builder floo...
# ...                                                                  ...
# QUALITY_SCORE                                                        NaN
# FURNISHING_ATTRIBUTES                                                NaN
# PRICE_CLEANED                                                        NaN
# AREA_CLEANED                                                         NaN
# PRICE_PER_SQFT                                                       NaN
#
#                        freq             mean              std        min  \
# PROP_ID                   1              NaN              NaN        NaN
# PHOTO_URL                14              NaN              NaN        NaN
# MEDIUM_PHOTO_URL         14              NaN              NaN        NaN
# PREFERENCE             6361              NaN              NaN        NaN
# DESCRIPTION              51              NaN              NaN        NaN
# ...                     ...              ...              ...        ...
# QUALITY_SCORE           NaN              NaN              NaN        NaN
# FURNISHING_ATTRIBUTES   NaN              NaN              NaN        NaN
# PRICE_CLEANED           NaN  29108448.710381  40716730.772293    11000.0
# AREA_CLEANED            NaN      2351.566494      3373.849651      242.0
# PRICE_PER_SQFT          NaN     11268.484726      7275.702019  11.111111
#
#                                25%           50%           75%            max
# PROP_ID                        NaN           NaN           NaN            NaN
# PHOTO_URL                      NaN           NaN           NaN            NaN
# MEDIUM_PHOTO_URL               NaN           NaN           NaN            NaN
# PREFERENCE                     NaN           NaN           NaN            NaN
# DESCRIPTION                    NaN           NaN           NaN            NaN
# ...                            ...           ...           ...            ...
# QUALITY_SCORE                  NaN           NaN           NaN            NaN
# FURNISHING_ATTRIBUTES          NaN           NaN           NaN            NaN
# PRICE_CLEANED           13500000.0    20000000.0    34250000.0   1500000000.0
# AREA_CLEANED                1620.0        2050.0        2686.0       258879.0
# PRICE_PER_SQFT         7669.343079  10142.238714  13566.585092  159057.437408
#
# [70 rows x 11 columns]

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Numerical Columns

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[num_cols].hist(figsize=(15, 10), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Categorical Columns

# %%
cat_cols = df.select_dtypes(include='object').nunique()
cat_cols = cat_cols[cat_cols < 50].index  # Focus on lower-cardinality columns

for col in cat_cols:
    plt.figure(figsize=(10, 4))
    sns.countplot(y=df[col], order=df[col].value_counts().index)
    plt.title(f"Distribution of {col}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Price and Area Distributoins

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['PRICE_CLEANED'], bins=50, kde=True)
plt.title("Distribution of Property Price (₹)")
plt.xscale('log')
plt.xlabel("Price (Log Scale)")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['AREA_CLEANED'], bins=50, kde=True)
plt.title("Distribution of Area (sq.ft.)")
plt.xscale('log')
plt.xlabel("Area (Log Scale)")
plt.show()

# %% [markdown]
# ## Price per Sq.Ft by City Locality

# %%
plt.figure(figsize=(12, 6))
top_cities = df['CITY'].value_counts().nlargest(10).index
sns.boxplot(data=df[df['CITY'].isin(top_cities)], x='CITY', y='PRICE_PER_SQFT')
plt.xticks(rotation=45)
plt.title("Price per Sq.Ft Distribution Across Top 10 Mumbai Localities")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Impact of Bedrooms on Price per Sq. Ft.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df["BEDROOM_NUM"].astype("category"), y=df["PRICE_PER_SQFT"])
plt.title("Price per Sq.Ft by Bedroom Count")
plt.xlabel("Number of Bedrooms")
plt.ylabel("Price per Sq.Ft")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Outlier Detection (Price per Sq.Ft)

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['PRICE_PER_SQFT'])
plt.title("Outlier Check: PRICE_PER_SQFT")
plt.show()

# %%
df.to_csv("../data/processed/gurgaon_summary_cleaned.csv", index=False)
