# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv("../data/processed/kolkata_summary.csv")

# %%
df.head()
# Out:
#      PROP_ID PREFERENCE                                        DESCRIPTION  \
# 0  J71214794          S  Experience a new style of living with Bhawani ...
# 1  F70835394          S  Let your dream of owning a flat come true with...
# 2  P69854924          S  Book your 4 BHK apartment in DTC Capital City,...
# 3  E69854912          S  Make DTC Capital City your next home. Book you...
# 4  R69167152          S  Book a spectacular property in Sai Sarovaar th...
#
#            PROPERTY_TYPE           CITY  TRANSACT_TYPE   OWNTYPE  BEDROOM_NUM  \
# 0  Residential Apartment  Kolkata North            2.0  Freehold          2.0
# 1  Residential Apartment  Kolkata South            2.0  Freehold          1.0
# 2  Residential Apartment   Kolkata East            2.0  Freehold          4.0
# 3  Residential Apartment   Kolkata East            2.0  Freehold          2.0
# 4  Residential Apartment   Kolkata East            2.0  Freehold          3.0
#
#    PRICE_PER_UNIT_AREA  FURNISH  ... FLOOR_NUM CARPET_SQFT  SUPERBUILTUP_SQFT  \
# 0               4239.0        0  ...       NaN         NaN              920.0
# 1               5100.0        0  ...       NaN         NaN              535.0
# 2               4742.0        0  ...       NaN         NaN             1940.0
# 3               4615.0        0  ...       NaN         NaN              910.0
# 4               4700.0        0  ...       NaN         NaN             1163.0
#
#   BUILTUP_SQFT SUPER_AREA  SUPERAREA_UNIT SUPER_SQFT PRICE_CLEANED  \
# 0          NaN        NaN             NaN        NaN     3900000.0
# 1          NaN        NaN             NaN        NaN     2728000.0
# 2          NaN        NaN             NaN        NaN     9200000.0
# 3          NaN        NaN             NaN        NaN     4200000.0
# 4          NaN        NaN             NaN        NaN     5466000.0
#
#   AREA_CLEANED PRICE_PER_SQFT
# 0        920.0    4239.130435
# 1        535.0    5099.065421
# 2       1940.0    4742.268041
# 3        910.0    4615.384615
# 4       1163.0    4699.914015
#
# [5 rows x 38 columns]

# %%
df.shape
# Out:
# (5381, 38)

# %%
df.columns
# Out:
# Index(['PROP_ID', 'PREFERENCE', 'DESCRIPTION', 'PROPERTY_TYPE', 'CITY',
#        'TRANSACT_TYPE', 'OWNTYPE', 'BEDROOM_NUM', 'PRICE_PER_UNIT_AREA',
#        'FURNISH', 'FACING', 'AGE', 'TOTAL_FLOOR', 'FEATURES', 'PROP_NAME',
#        'PRICE_SQFT', 'MAP_DETAILS', 'AMENITIES', 'AREA', 'PRICE',
#        'PROP_HEADING', 'SECONDARY_TAGS', 'TOTAL_LANDMARK_COUNT',
#        'FORMATTED_LANDMARK_DETAILS', 'SOCIETY_NAME', 'BUILDING_NAME',
#        'location', 'BALCONY_NUM', 'FLOOR_NUM', 'CARPET_SQFT',
#        'SUPERBUILTUP_SQFT', 'BUILTUP_SQFT', 'SUPER_AREA', 'SUPERAREA_UNIT',
#        'SUPER_SQFT', 'PRICE_CLEANED', 'AREA_CLEANED', 'PRICE_PER_SQFT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PROP_ID                        object
# PREFERENCE                     object
# DESCRIPTION                    object
# PROPERTY_TYPE                  object
# CITY                           object
# TRANSACT_TYPE                 float64
# OWNTYPE                        object
# BEDROOM_NUM                   float64
# PRICE_PER_UNIT_AREA           float64
# FURNISH                         int64
# FACING                         object
# AGE                            object
# TOTAL_FLOOR                   float64
# FEATURES                       object
# PROP_NAME                      object
# PRICE_SQFT                    float64
# MAP_DETAILS                    object
# AMENITIES                      object
# AREA                           object
# PRICE                          object
# PROP_HEADING                   object
# SECONDARY_TAGS                 object
# TOTAL_LANDMARK_COUNT          float64
# FORMATTED_LANDMARK_DETAILS     object
# SOCIETY_NAME                   object
# BUILDING_NAME                  object
# location                       object
# BALCONY_NUM                   float64
# FLOOR_NUM                      object
# CARPET_SQFT                   float64
# SUPERBUILTUP_SQFT             float64
# BUILTUP_SQFT                  float64
# SUPER_AREA                    float64
# SUPERAREA_UNIT                float64
# SUPER_SQFT                    float64
# PRICE_CLEANED                 float64
# AREA_CLEANED                  float64
# PRICE_PER_SQFT                float64
# dtype: object

# %%
missing = df.isna().sum().sort_values(ascending=False)
print(missing[missing > 0])
# Out:
# SUPER_AREA                    5381
# SUPERAREA_UNIT                5381
# SUPER_SQFT                    5368
# FLOOR_NUM                     4381
# BUILTUP_SQFT                  4265
# CARPET_SQFT                   3961
# TRANSACT_TYPE                 1054
# OWNTYPE                       1052
# FACING                         867
# AMENITIES                      483
# BALCONY_NUM                    339
# TOTAL_LANDMARK_COUNT           140
# FORMATTED_LANDMARK_DETAILS     140
# BUILDING_NAME                   70
# PROP_NAME                       57
# SOCIETY_NAME                    57
# TOTAL_FLOOR                     51
# BEDROOM_NUM                      4
# dtype: int64

# %%
df.describe(include='all').T
# Out:
#                              count unique  \
# PROP_ID                       5381   5381
# PREFERENCE                    5381      3
# DESCRIPTION                   5381   5175
# PROPERTY_TYPE                 5381      2
# CITY                          5381      5
# TRANSACT_TYPE               4327.0    NaN
# OWNTYPE                       4329      4
# BEDROOM_NUM                 5377.0    NaN
# PRICE_PER_UNIT_AREA         5381.0    NaN
# FURNISH                     5381.0    NaN
# FACING                        4514      8
# AGE                           5381      5
# TOTAL_FLOOR                 5330.0    NaN
# FEATURES                      5381   2373
# PROP_NAME                     5324   1881
# PRICE_SQFT                  5381.0    NaN
# MAP_DETAILS                   5381   2142
# AMENITIES                     4898   2698
# AREA                          5381   1319
# PRICE                         5381   1394
# PROP_HEADING                  5381    812
# SECONDARY_TAGS                5381     32
# TOTAL_LANDMARK_COUNT        5241.0    NaN
# FORMATTED_LANDMARK_DETAILS    5241   1125
# SOCIETY_NAME                  5324   1882
# BUILDING_NAME                 5311   1877
# location                      5381   1610
# BALCONY_NUM                 5042.0    NaN
# FLOOR_NUM                     1000     27
# CARPET_SQFT                 1420.0    NaN
# SUPERBUILTUP_SQFT           5381.0    NaN
# BUILTUP_SQFT                1116.0    NaN
# SUPER_AREA                     0.0    NaN
# SUPERAREA_UNIT                 0.0    NaN
# SUPER_SQFT                    13.0    NaN
# PRICE_CLEANED               5381.0    NaN
# AREA_CLEANED                5381.0    NaN
# PRICE_PER_SQFT              5381.0    NaN
#
#                                                                           top  \
# PROP_ID                                                             I41581465
# PREFERENCE                                                                  S
# DESCRIPTION                 Premium location. Close to all transport. Posh...
# PROPERTY_TYPE                                           Residential Apartment
# CITY                                                            Kolkata South
# TRANSACT_TYPE                                                             NaN
# OWNTYPE                                                              Freehold
# BEDROOM_NUM                                                               NaN
# PRICE_PER_UNIT_AREA                                                       NaN
# FURNISH                                                                   NaN
# FACING                                                             South-East
# AGE                                                     1-5 Year Old Property
# TOTAL_FLOOR                                                               NaN
# FEATURES                                                                    N
# PROP_NAME                                                          On Request
# PRICE_SQFT                                                                NaN
# MAP_DETAILS                 {'LATITUDE': '22.6006912', 'LONGITUDE': '88.46...
# AMENITIES                                       5,17,20,21,23,24,6,19,101,102
# AREA                                                              1250 sq.ft.
# PRICE                                                                    75 L
# PROP_HEADING                                           3 BHK Flat in New Town
# SECONDARY_TAGS                                    ['READY TO MOVE', 'RESALE']
# TOTAL_LANDMARK_COUNT                                                      NaN
# FORMATTED_LANDMARK_DETAILS  [{'category': 'ReligiousPlace', 'text': '2 Rel...
# SOCIETY_NAME                                                       On Request
# BUILDING_NAME                                                      On Request
# location                    {'CITY': '28', 'CITY_NAME': 'Kolkata East', 'L...
# BALCONY_NUM                                                               NaN
# FLOOR_NUM                                                                  10
# CARPET_SQFT                                                               NaN
# SUPERBUILTUP_SQFT                                                         NaN
# BUILTUP_SQFT                                                              NaN
# SUPER_AREA                                                                NaN
# SUPERAREA_UNIT                                                            NaN
# SUPER_SQFT                                                                NaN
# PRICE_CLEANED                                                             NaN
# AREA_CLEANED                                                              NaN
# PRICE_PER_SQFT                                                            NaN
#
#                             freq            mean              std       min  \
# PROP_ID                        1             NaN              NaN       NaN
# PREFERENCE                  4329             NaN              NaN       NaN
# DESCRIPTION                   20             NaN              NaN       NaN
# PROPERTY_TYPE               5235             NaN              NaN       NaN
# CITY                        2237             NaN              NaN       NaN
# TRANSACT_TYPE                NaN        1.077652         0.267654       1.0
# OWNTYPE                     4203             NaN              NaN       NaN
# BEDROOM_NUM                  NaN        2.605356         0.746839       1.0
# PRICE_PER_UNIT_AREA          NaN     4930.942204      4026.938533       0.0
# FURNISH                      NaN        1.980115         1.009147       0.0
# FACING                      1384             NaN              NaN       NaN
# AGE                         2520             NaN              NaN       NaN
# TOTAL_FLOOR                  NaN        9.984615         8.358934       1.0
# FEATURES                     503             NaN              NaN       NaN
# PROP_NAME                    251             NaN              NaN       NaN
# PRICE_SQFT                   NaN     4930.942204      4026.938533       0.0
# MAP_DETAILS                  303             NaN              NaN       NaN
# AMENITIES                    146             NaN              NaN       NaN
# AREA                          92             NaN              NaN       NaN
# PRICE                         86             NaN              NaN       NaN
# PROP_HEADING                 483             NaN              NaN       NaN
# SECONDARY_TAGS              2758             NaN              NaN       NaN
# TOTAL_LANDMARK_COUNT         NaN        29.28983        15.922623       1.0
# FORMATTED_LANDMARK_DETAILS   182             NaN              NaN       NaN
# SOCIETY_NAME                 253             NaN              NaN       NaN
# BUILDING_NAME                249             NaN              NaN       NaN
# location                     607             NaN              NaN       NaN
# BALCONY_NUM                  NaN        1.235224          0.58328       0.0
# FLOOR_NUM                    181             NaN              NaN       NaN
# CARPET_SQFT                  NaN      991.362937       547.634889       0.0
# SUPERBUILTUP_SQFT            NaN     2324.344653     53863.751399     130.0
# BUILTUP_SQFT                 NaN     1097.337437       635.929619       0.0
# SUPER_AREA                   NaN             NaN              NaN       NaN
# SUPERAREA_UNIT               NaN             NaN              NaN       NaN
# SUPER_SQFT                   NaN             0.0              0.0       0.0
# PRICE_CLEANED                NaN  7335750.878461  12445712.673083      45.0
# AREA_CLEANED                 NaN     2324.344653     53863.751399     130.0
# PRICE_PER_SQFT               NaN     4806.563168       3820.83177  0.051136
#
#                                     25%          50%          75%  \
# PROP_ID                             NaN          NaN          NaN
# PREFERENCE                          NaN          NaN          NaN
# DESCRIPTION                         NaN          NaN          NaN
# PROPERTY_TYPE                       NaN          NaN          NaN
# CITY                                NaN          NaN          NaN
# TRANSACT_TYPE                       1.0          1.0          1.0
# OWNTYPE                             NaN          NaN          NaN
# BEDROOM_NUM                         2.0          3.0          3.0
# PRICE_PER_UNIT_AREA              2969.0       4500.0       6489.0
# FURNISH                             2.0          2.0          2.0
# FACING                              NaN          NaN          NaN
# AGE                                 NaN          NaN          NaN
# TOTAL_FLOOR                         4.0          5.0         14.0
# FEATURES                            NaN          NaN          NaN
# PROP_NAME                           NaN          NaN          NaN
# PRICE_SQFT                       2969.0       4500.0       6489.0
# MAP_DETAILS                         NaN          NaN          NaN
# AMENITIES                           NaN          NaN          NaN
# AREA                                NaN          NaN          NaN
# PRICE                               NaN          NaN          NaN
# PROP_HEADING                        NaN          NaN          NaN
# SECONDARY_TAGS                      NaN          NaN          NaN
# TOTAL_LANDMARK_COUNT               15.0         29.0         47.0
# FORMATTED_LANDMARK_DETAILS          NaN          NaN          NaN
# SOCIETY_NAME                        NaN          NaN          NaN
# BUILDING_NAME                       NaN          NaN          NaN
# location                            NaN          NaN          NaN
# BALCONY_NUM                         1.0          1.0          1.0
# FLOOR_NUM                           NaN          NaN          NaN
# CARPET_SQFT                       700.0        900.0       1132.0
# SUPERBUILTUP_SQFT                 890.0       1140.0       1476.0
# BUILTUP_SQFT                      751.0        964.0       1261.0
# SUPER_AREA                          NaN          NaN          NaN
# SUPERAREA_UNIT                      NaN          NaN          NaN
# SUPER_SQFT                          0.0          0.0          0.0
# PRICE_CLEANED                 2200000.0    4500000.0    8200000.0
# AREA_CLEANED                      890.0       1140.0       1476.0
# PRICE_PER_SQFT              2937.976061  4499.525166  6348.020911
#
#                                      max
# PROP_ID                              NaN
# PREFERENCE                           NaN
# DESCRIPTION                          NaN
# PROPERTY_TYPE                        NaN
# CITY                                 NaN
# TRANSACT_TYPE                        2.0
# OWNTYPE                              NaN
# BEDROOM_NUM                          9.0
# PRICE_PER_UNIT_AREA              57333.0
# FURNISH                              4.0
# FACING                               NaN
# AGE                                  NaN
# TOTAL_FLOOR                         40.0
# FEATURES                             NaN
# PROP_NAME                            NaN
# PRICE_SQFT                       57333.0
# MAP_DETAILS                          NaN
# AMENITIES                            NaN
# AREA                                 NaN
# PRICE                                NaN
# PROP_HEADING                         NaN
# SECONDARY_TAGS                       NaN
# TOTAL_LANDMARK_COUNT                50.0
# FORMATTED_LANDMARK_DETAILS           NaN
# SOCIETY_NAME                         NaN
# BUILDING_NAME                        NaN
# location                             NaN
# BALCONY_NUM                          4.0
# FLOOR_NUM                            NaN
# CARPET_SQFT                       8250.0
# SUPERBUILTUP_SQFT              2994000.0
# BUILTUP_SQFT                      9500.0
# SUPER_AREA                           NaN
# SUPERAREA_UNIT                       NaN
# SUPER_SQFT                           0.0
# PRICE_CLEANED                330000000.0
# AREA_CLEANED                   2994000.0
# PRICE_PER_SQFT              57333.333333

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Numerical Columns

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[num_cols].hist(figsize=(15, 10), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Categorical Columns

# %%
cat_cols = df.select_dtypes(include='object').nunique()
cat_cols = cat_cols[cat_cols < 50].index  # Focus on lower-cardinality columns

for col in cat_cols:
    plt.figure(figsize=(10, 4))
    sns.countplot(y=df[col], order=df[col].value_counts().index)
    plt.title(f"Distribution of {col}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Price and Area Distributoins

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['PRICE_CLEANED'], bins=50, kde=True)
plt.title("Distribution of Property Price (₹)")
plt.xscale('log')
plt.xlabel("Price (Log Scale)")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['AREA_CLEANED'], bins=50, kde=True)
plt.title("Distribution of Area (sq.ft.)")
plt.xscale('log')
plt.xlabel("Area (Log Scale)")
plt.show()

# %% [markdown]
# ## Price per Sq.Ft by City Locality

# %%
plt.figure(figsize=(12, 6))
top_cities = df['CITY'].value_counts().nlargest(10).index
sns.boxplot(data=df[df['CITY'].isin(top_cities)], x='CITY', y='PRICE_PER_SQFT')
plt.xticks(rotation=45)
plt.title("Price per Sq.Ft Distribution Across Top 10 Mumbai Localities")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Impact of Bedrooms on Price per Sq. Ft.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df["BEDROOM_NUM"].astype("category"), y=df["PRICE_PER_SQFT"])
plt.title("Price per Sq.Ft by Bedroom Count")
plt.xlabel("Number of Bedrooms")
plt.ylabel("Price per Sq.Ft")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Outlier Detection (Price per Sq.Ft)

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['PRICE_PER_SQFT'])
plt.title("Outlier Check: PRICE_PER_SQFT")
plt.show()

# %%
df.to_csv("../data/processed/kolkata_summary_cleaned.csv", index=False)
