# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the processed Mumbai dataset
df = pd.read_csv("../data/processed/mumbai_summary.csv")

# %%
df.head()
# Out:
#        SPID    PROP_ID PREFERENCE  \
# 0  69306824  X69306824          S
# 1  70915032  R70915032          S
# 2  70916930  G70916930          P
# 3  70484400  H70484400          P
# 4  70484128  A70484128          P
#
#                                          DESCRIPTION          PROPERTY_TYPE  \
# 0  New brand 3bhk farmhouse with 68 guntha land f...             Farm House
# 1  Our residential plots & commercial plots are a...       Residential Land
# 2  Spacious bedroom with \nDouble size bed with d...  Residential Apartment
# 3  Pg for boys and girls available with price of:...  Residential Apartment
# 4  Pg for boys and girls in thane with below pric...  Residential Apartment
#
#                   CITY  TRANSACT_TYPE   OWNTYPE  BEDROOM_NUM  \
# 0  Mumbai Beyond Thane            1.0  Freehold          3.0
# 1          Navi Mumbai            1.0  Freehold          NaN
# 2                Thane            NaN       NaN          1.0
# 3                Thane            NaN       NaN          4.0
# 4                Thane            NaN       NaN          4.0
#
#    PRICE_PER_UNIT_AREA  ...  TOTAL_LANDMARK_COUNT  \
# 0             477941.0  ...                  14.0
# 1                381.0  ...                   NaN
# 2                 51.0  ...                  49.0
# 3                  6.0  ...                  39.0
# 4                  6.0  ...                  50.0
#
#                           FORMATTED_LANDMARK_DETAILS  \
# 0                          [{'text': '9 Hospitals'}]
# 1                                                NaN
# 2  [{'text': '2 Religious Places'}, {'text': '1 A...
# 3  [{'text': '1 Shopping'}, {'text': '3 Religious...
# 4  [{'text': '1 Shopping'}, {'text': '2 Religious...
#
#                  SOCIETY_NAME               BUILDING_NAME  \
# 0                         NaN                         NaN
# 1                   city prop                   city prop
# 2             Highway Darshan             Highway Darshan
# 3  Terraform Petunia, G Corp   Terraform Petunia, G Corp
# 4                         nul                         nul
#
#                                             location BALCONY_NUM  FLOOR_NUM  \
# 0  {'CITY': '274', 'CITY_NAME': 'Mumbai Beyond Th...         1.0        NaN
# 1  {'CITY': '15', 'CITY_NAME': 'Navi Mumbai', 'BU...         NaN        NaN
# 2  {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...         1.0        NaN
# 3  {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...         2.0        NaN
# 4  {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...         2.0        NaN
#
#    PRICE_CLEANED AREA_CLEANED PRICE_PER_SQFT
# 0     32500000.0      74051.0     438.886713
# 1       415000.0       1089.0     381.083563
# 2        20000.0        390.0      51.282051
# 3         8000.0       1250.0       6.400000
# 4         8000.0       1250.0       6.400000
#
# [5 rows x 58 columns]

# %%
df.shape
# Out:
# (9255, 58)

# %%
df.columns
# Out:
# Index(['SPID', 'PROP_ID', 'PREFERENCE', 'DESCRIPTION', 'PROPERTY_TYPE', 'CITY',
#        'TRANSACT_TYPE', 'OWNTYPE', 'BEDROOM_NUM', 'PRICE_PER_UNIT_AREA',
#        'FURNISH', 'FACING', 'AGE', 'TOTAL_FLOOR', 'FEATURES', 'REGISTER_DATE',
#        'POSTING_DATE', 'UPDATE_DATE', 'CLASS', 'RES_COM', 'PROP_NAME',
#        'PROPERTY_NUMBER', 'MIN_PRICE', 'MAX_PRICE', 'PRICE_SQFT', 'PROJ_ID',
#        'BUILDING_ID', 'VERIFIED', 'MAP_DETAILS', 'MIN_AREA_SQFT',
#        'MAX_AREA_SQFT', 'AMENITIES', 'ALT_TAG', 'PRODUCT_TYPE', 'TOP_USPS',
#        'EXPIRY_DATE', 'PROPERTY_TYPE__U', 'AREA', 'SECONDARY_AREA', 'PRICE',
#        'PROP_HEADING', 'VALUE_LABEL', 'CLASS_HEADING', 'CLASS_LABEL',
#        'REGISTER_DATE__U', 'REGISTERED_DAYS', 'PRIMARY_TAGS', 'SECONDARY_TAGS',
#        'TOTAL_LANDMARK_COUNT', 'FORMATTED_LANDMARK_DETAILS', 'SOCIETY_NAME',
#        'BUILDING_NAME', 'location', 'BALCONY_NUM', 'FLOOR_NUM',
#        'PRICE_CLEANED', 'AREA_CLEANED', 'PRICE_PER_SQFT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# SPID                            int64
# PROP_ID                        object
# PREFERENCE                     object
# DESCRIPTION                    object
# PROPERTY_TYPE                  object
# CITY                           object
# TRANSACT_TYPE                 float64
# OWNTYPE                        object
# BEDROOM_NUM                   float64
# PRICE_PER_UNIT_AREA           float64
# FURNISH                         int64
# FACING                         object
# AGE                            object
# TOTAL_FLOOR                    object
# FEATURES                       object
# REGISTER_DATE                  object
# POSTING_DATE                  float64
# UPDATE_DATE                     int64
# CLASS                          object
# RES_COM                        object
# PROP_NAME                      object
# PROPERTY_NUMBER                 int64
# MIN_PRICE                       int64
# MAX_PRICE                       int64
# PRICE_SQFT                    float64
# PROJ_ID                         int64
# BUILDING_ID                     int64
# VERIFIED                       object
# MAP_DETAILS                    object
# MIN_AREA_SQFT                 float64
# MAX_AREA_SQFT                 float64
# AMENITIES                      object
# ALT_TAG                        object
# PRODUCT_TYPE                   object
# TOP_USPS                       object
# EXPIRY_DATE                    object
# PROPERTY_TYPE__U               object
# AREA                           object
# SECONDARY_AREA                 object
# PRICE                          object
# PROP_HEADING                   object
# VALUE_LABEL                    object
# CLASS_HEADING                  object
# CLASS_LABEL                    object
# REGISTER_DATE__U               object
# REGISTERED_DAYS                object
# PRIMARY_TAGS                   object
# SECONDARY_TAGS                 object
# TOTAL_LANDMARK_COUNT          float64
# FORMATTED_LANDMARK_DETAILS     object
# SOCIETY_NAME                   object
# BUILDING_NAME                  object
# location                       object
# BALCONY_NUM                   float64
# FLOOR_NUM                      object
# PRICE_CLEANED                 float64
# AREA_CLEANED                  float64
# PRICE_PER_SQFT                float64
# dtype: object

# %%
missing = df.isna().sum().sort_values(ascending=False)
print(missing[missing > 0])
# Out:
# FLOOR_NUM                     7240
# TOP_USPS                      5846
# FACING                        5128
# AMENITIES                     4290
# BALCONY_NUM                   4111
# VALUE_LABEL                   2637
# OWNTYPE                       2637
# TRANSACT_TYPE                 2637
# TOTAL_FLOOR                   1314
# ALT_TAG                       1057
# POSTING_DATE                   411
# FORMATTED_LANDMARK_DETAILS     176
# TOTAL_LANDMARK_COUNT           176
# PROP_NAME                      109
# SOCIETY_NAME                   109
# BUILDING_NAME                  109
# BEDROOM_NUM                     73
# AGE                             64
# dtype: int64

# %%
df.describe(include='all').T
# Out:
#                              count unique  \
# SPID                        9255.0    NaN
# PROP_ID                       9255   9250
# PREFERENCE                    9255      3
# DESCRIPTION                   9255   9055
# PROPERTY_TYPE                 9255      7
# CITY                          9255      9
# TRANSACT_TYPE               6618.0    NaN
# OWNTYPE                       6618      4
# BEDROOM_NUM                 9182.0    NaN
# PRICE_PER_UNIT_AREA         9255.0    NaN
# FURNISH                     9255.0    NaN
# FACING                        4127      8
# AGE                           9191      5
# TOTAL_FLOOR                   7941     41
# FEATURES                      9255   2888
# REGISTER_DATE                 9255    170
# POSTING_DATE                8844.0    NaN
# UPDATE_DATE                 9255.0    NaN
# CLASS                         9255      3
# RES_COM                       9255      1
# PROP_NAME                     9146   3471
# PROPERTY_NUMBER             9255.0    NaN
# MIN_PRICE                   9255.0    NaN
# MAX_PRICE                   9255.0    NaN
# PRICE_SQFT                  9255.0    NaN
# PROJ_ID                     9255.0    NaN
# BUILDING_ID                 9255.0    NaN
# VERIFIED                      9255      2
# MAP_DETAILS                   9255   3323
# MIN_AREA_SQFT               9255.0    NaN
# MAX_AREA_SQFT               9255.0    NaN
# AMENITIES                     4965   3297
# ALT_TAG                       8198   4047
# PRODUCT_TYPE                  9255      5
# TOP_USPS                      3409   1711
# EXPIRY_DATE                   9255    180
# PROPERTY_TYPE__U              9255      7
# AREA                          9255   2540
# SECONDARY_AREA                9255   2540
# PRICE                         9255   2932
# PROP_HEADING                  9255   1702
# VALUE_LABEL                   6618      4
# CLASS_HEADING                 9255    812
# CLASS_LABEL                   9255      3
# REGISTER_DATE__U              9255   8457
# REGISTERED_DAYS               9255     33
# PRIMARY_TAGS                  9255      2
# SECONDARY_TAGS                9255     52
# TOTAL_LANDMARK_COUNT        9079.0    NaN
# FORMATTED_LANDMARK_DETAILS    9079   2014
# SOCIETY_NAME                  9146   3471
# BUILDING_NAME                 9146   3471
# location                      9255   4669
# BALCONY_NUM                 5144.0    NaN
# FLOOR_NUM                     2015     59
# PRICE_CLEANED               9255.0    NaN
# AREA_CLEANED                9255.0    NaN
# PRICE_PER_SQFT              9255.0    NaN
#
#                                                                           top  \
# SPID                                                                      NaN
# PROP_ID                                                             H68802070
# PREFERENCE                                                                  S
# DESCRIPTION                 All modes of public conveyance such as tmt/nmt...
# PROPERTY_TYPE                                           Residential Apartment
# CITY                                                              Navi Mumbai
# TRANSACT_TYPE                                                             NaN
# OWNTYPE                                                              Freehold
# BEDROOM_NUM                                                               NaN
# PRICE_PER_UNIT_AREA                                                       NaN
# FURNISH                                                                   NaN
# FACING                                                                   East
# AGE                                                        Under Construction
# TOTAL_FLOOR                                                                20
# FEATURES                                                                    N
# REGISTER_DATE                                                  08th Aug, 2023
# POSTING_DATE                                                              NaN
# UPDATE_DATE                                                               NaN
# CLASS                                                                       A
# RES_COM                                                                     R
# PROP_NAME                                                         Lodha Amara
# PROPERTY_NUMBER                                                           NaN
# MIN_PRICE                                                                 NaN
# MAX_PRICE                                                                 NaN
# PRICE_SQFT                                                                NaN
# PROJ_ID                                                                   NaN
# BUILDING_ID                                                               NaN
# VERIFIED                                                                    N
# MAP_DETAILS                 {'LATITUDE': '19.233686', 'LONGITUDE': '72.988...
# MIN_AREA_SQFT                                                             NaN
# MAX_AREA_SQFT                                                             NaN
# AMENITIES                                       5,17,20,21,23,24,6,19,101,102
# ALT_TAG                                                    Lodha Amara Others
# PRODUCT_TYPE                                                   PSEUDO_LISTING
# TOP_USPS                    ['Food Service Included', 'Laundry Service ava...
# EXPIRY_DATE                                               2023-09-16 00:00:00
# PROPERTY_TYPE__U                                        Residential Apartment
# AREA                                                              1000 sq.ft.
# SECONDARY_AREA                                                     92.9 sq.m.
# PRICE                                                              15,000/Bed
# PROP_HEADING                                        3 BHK Flat in Mulund West
# VALUE_LABEL                                                          Freehold
# CLASS_HEADING                                                           Owner
# CLASS_LABEL                                                            Dealer
# REGISTER_DATE__U                                          2023-07-17 00:00:00
# REGISTERED_DAYS                                                   1 month ago
# PRIMARY_TAGS                                                               []
# SECONDARY_TAGS                  ['UNDER CONSTRUCTION', 'NEW BOOKING', 'RERA']
# TOTAL_LANDMARK_COUNT                                                      NaN
# FORMATTED_LANDMARK_DETAILS  [{'text': '1 Railway Station'}, {'text': '1 Me...
# SOCIETY_NAME                                                      Lodha Amara
# BUILDING_NAME                                                     Lodha Amara
# location                    {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...
# BALCONY_NUM                                                               NaN
# FLOOR_NUM                                                                  10
# PRICE_CLEANED                                                             NaN
# AREA_CLEANED                                                              NaN
# PRICE_PER_SQFT                                                            NaN
#
#                             freq                  mean                std  \
# SPID                         NaN       69067039.063965     4944900.382882
# PROP_ID                        2                   NaN                NaN
# PREFERENCE                  6618                   NaN                NaN
# DESCRIPTION                   56                   NaN                NaN
# PROPERTY_TYPE               8877                   NaN                NaN
# CITY                        2165                   NaN                NaN
# TRANSACT_TYPE                NaN              1.612874            0.48713
# OWNTYPE                     5672                   NaN                NaN
# BEDROOM_NUM                  NaN              2.225986           0.998315
# PRICE_PER_UNIT_AREA          NaN          22845.972663      126010.616998
# FURNISH                      NaN              1.282982            1.50806
# FACING                      1809                   NaN                NaN
# AGE                         3621                   NaN                NaN
# TOTAL_FLOOR                  680                   NaN                NaN
# FEATURES                    4393                   NaN                NaN
# REGISTER_DATE                345                   NaN                NaN
# POSTING_DATE                 NaN  1688120586396.540039  5817663318.728238
# UPDATE_DATE                  NaN  1690567720247.758057  2944520669.906817
# CLASS                       7957                   NaN                NaN
# RES_COM                     9255                   NaN                NaN
# PROP_NAME                     73                   NaN                NaN
# PROPERTY_NUMBER              NaN              1.848298            2.46727
# MIN_PRICE                    NaN       19565141.344571    35712746.138665
# MAX_PRICE                    NaN       21487040.598703     39984093.74086
# PRICE_SQFT                   NaN          22845.972663      126010.616998
# PROJ_ID                      NaN         165058.039546      163360.039585
# BUILDING_ID                  NaN          431096.14403      437710.089768
# VERIFIED                    7944                   NaN                NaN
# MAP_DETAILS                   60                   NaN                NaN
# MIN_AREA_SQFT                NaN            116.659768         955.021908
# MAX_AREA_SQFT                NaN            121.591145         955.120201
# AMENITIES                    152                   NaN                NaN
# ALT_TAG                       40                   NaN                NaN
# PRODUCT_TYPE                4056                   NaN                NaN
# TOP_USPS                      88                   NaN                NaN
# EXPIRY_DATE                  940                   NaN                NaN
# PROPERTY_TYPE__U            8877                   NaN                NaN
# AREA                         143                   NaN                NaN
# SECONDARY_AREA               143                   NaN                NaN
# PRICE                         82                   NaN                NaN
# PROP_HEADING                 133                   NaN                NaN
# VALUE_LABEL                 5672                   NaN                NaN
# CLASS_HEADING               1020                   NaN                NaN
# CLASS_LABEL                 7957                   NaN                NaN
# REGISTER_DATE__U              35                   NaN                NaN
# REGISTERED_DAYS             3269                   NaN                NaN
# PRIMARY_TAGS                9251                   NaN                NaN
# SECONDARY_TAGS              2240                   NaN                NaN
# TOTAL_LANDMARK_COUNT         NaN             27.528362          18.815357
# FORMATTED_LANDMARK_DETAILS   186                   NaN                NaN
# SOCIETY_NAME                  73                   NaN                NaN
# BUILDING_NAME                 73                   NaN                NaN
# location                      59                   NaN                NaN
# BALCONY_NUM                  NaN              1.165241           1.234946
# FLOOR_NUM                    253                   NaN                NaN
# PRICE_CLEANED                NaN       12912776.336078    32601713.981763
# AREA_CLEANED                 NaN           1282.256294       10279.861874
# PRICE_PER_SQFT               NaN          10585.068392       15474.580522
#
#                                         min              25%              50%  \
# SPID                              5344653.0       69464478.0       70366558.0
# PROP_ID                                 NaN              NaN              NaN
# PREFERENCE                              NaN              NaN              NaN
# DESCRIPTION                             NaN              NaN              NaN
# PROPERTY_TYPE                           NaN              NaN              NaN
# CITY                                    NaN              NaN              NaN
# TRANSACT_TYPE                           1.0              1.0              2.0
# OWNTYPE                                 NaN              NaN              NaN
# BEDROOM_NUM                             1.0              2.0              2.0
# PRICE_PER_UNIT_AREA                     0.0            100.0          16503.0
# FURNISH                                 0.0              0.0              1.0
# FACING                                  NaN              NaN              NaN
# AGE                                     NaN              NaN              NaN
# TOTAL_FLOOR                             NaN              NaN              NaN
# FEATURES                                NaN              NaN              NaN
# REGISTER_DATE                           NaN              NaN              NaN
# POSTING_DATE                1652967936000.0  1687758855250.0  1690224585000.0
# UPDATE_DATE                 1665145939000.0  1689928908000.0  1691450718000.0
# CLASS                                   NaN              NaN              NaN
# RES_COM                                 NaN              NaN              NaN
# PROP_NAME                               NaN              NaN              NaN
# PROPERTY_NUMBER                         1.0              1.0              1.0
# MIN_PRICE                               0.0          95000.0       10399818.0
# MAX_PRICE                             500.0          95000.0       11000000.0
# PRICE_SQFT                              0.0            100.0          16503.0
# PROJ_ID                                 0.0            920.0          88241.0
# BUILDING_ID                             0.0          22003.0         283565.0
# VERIFIED                                NaN              NaN              NaN
# MAP_DETAILS                             NaN              NaN              NaN
# MIN_AREA_SQFT                      1.393545        51.746971         73.39337
# MAX_AREA_SQFT                      1.393545          55.7418        78.224326
# AMENITIES                               NaN              NaN              NaN
# ALT_TAG                                 NaN              NaN              NaN
# PRODUCT_TYPE                            NaN              NaN              NaN
# TOP_USPS                                NaN              NaN              NaN
# EXPIRY_DATE                             NaN              NaN              NaN
# PROPERTY_TYPE__U                        NaN              NaN              NaN
# AREA                                    NaN              NaN              NaN
# SECONDARY_AREA                          NaN              NaN              NaN
# PRICE                                   NaN              NaN              NaN
# PROP_HEADING                            NaN              NaN              NaN
# VALUE_LABEL                             NaN              NaN              NaN
# CLASS_HEADING                           NaN              NaN              NaN
# CLASS_LABEL                             NaN              NaN              NaN
# REGISTER_DATE__U                        NaN              NaN              NaN
# REGISTERED_DAYS                         NaN              NaN              NaN
# PRIMARY_TAGS                            NaN              NaN              NaN
# SECONDARY_TAGS                          NaN              NaN              NaN
# TOTAL_LANDMARK_COUNT                    1.0             11.0             15.0
# FORMATTED_LANDMARK_DETAILS              NaN              NaN              NaN
# SOCIETY_NAME                            NaN              NaN              NaN
# BUILDING_NAME                           NaN              NaN              NaN
# location                                NaN              NaN              NaN
# BALCONY_NUM                             0.0              0.0              1.0
# FLOOR_NUM                               NaN              NaN              NaN
# PRICE_CLEANED                           0.0           4000.0         110000.0
# AREA_CLEANED                           15.0            590.0            812.5
# PRICE_PER_SQFT                          0.0            5.125            100.0
#
#                                         75%              max
# SPID                             70692177.0       71024450.0
# PROP_ID                                 NaN              NaN
# PREFERENCE                              NaN              NaN
# DESCRIPTION                             NaN              NaN
# PROPERTY_TYPE                           NaN              NaN
# CITY                                    NaN              NaN
# TRANSACT_TYPE                           2.0              2.0
# OWNTYPE                                 NaN              NaN
# BEDROOM_NUM                             3.0              9.0
# PRICE_PER_UNIT_AREA                 28000.0        8018867.0
# FURNISH                                 2.0              4.0
# FACING                                  NaN              NaN
# AGE                                     NaN              NaN
# TOTAL_FLOOR                             NaN              NaN
# FEATURES                                NaN              NaN
# REGISTER_DATE                           NaN              NaN
# POSTING_DATE                1691566568750.0  1692977235000.0
# UPDATE_DATE                 1692359266500.0  1692989618000.0
# CLASS                                   NaN              NaN
# RES_COM                                 NaN              NaN
# PROP_NAME                               NaN              NaN
# PROPERTY_NUMBER                         2.0             37.0
# MIN_PRICE                        23000000.0      910000000.0
# MAX_PRICE                        25500000.5      910000000.0
# PRICE_SQFT                          28000.0        8018867.0
# PROJ_ID                            335795.0         413829.0
# BUILDING_ID                       1003214.0        1125486.0
# VERIFIED                                NaN              NaN
# MAP_DETAILS                             NaN              NaN
# MIN_AREA_SQFT                     106.83845     60702.727297
# MAX_AREA_SQFT                    111.762309     60702.727297
# AMENITIES                               NaN              NaN
# ALT_TAG                                 NaN              NaN
# PRODUCT_TYPE                            NaN              NaN
# TOP_USPS                                NaN              NaN
# EXPIRY_DATE                             NaN              NaN
# PROPERTY_TYPE__U                        NaN              NaN
# AREA                                    NaN              NaN
# SECONDARY_AREA                          NaN              NaN
# PRICE                                   NaN              NaN
# PROP_HEADING                            NaN              NaN
# VALUE_LABEL                             NaN              NaN
# CLASS_HEADING                           NaN              NaN
# CLASS_LABEL                             NaN              NaN
# REGISTER_DATE__U                        NaN              NaN
# REGISTERED_DAYS                         NaN              NaN
# PRIMARY_TAGS                            NaN              NaN
# SECONDARY_TAGS                          NaN              NaN
# TOTAL_LANDMARK_COUNT                   49.0             50.0
# FORMATTED_LANDMARK_DETAILS              NaN              NaN
# SOCIETY_NAME                            NaN              NaN
# BUILDING_NAME                           NaN              NaN
# location                                NaN              NaN
# BALCONY_NUM                             2.0              4.0
# FLOOR_NUM                               NaN              NaN
# PRICE_CLEANED                    13500000.0      910000000.0
# AREA_CLEANED                         1200.0         653399.0
# PRICE_PER_SQFT                 18375.045897    258823.529412

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Numerical Columns

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[num_cols].hist(figsize=(15, 10), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Categorical Columns

# %%
cat_cols = df.select_dtypes(include='object').nunique()
cat_cols = cat_cols[cat_cols < 50].index  # Focus on lower-cardinality columns

for col in cat_cols:
    plt.figure(figsize=(10, 4))
    sns.countplot(y=df[col], order=df[col].value_counts().index)
    plt.title(f"Distribution of {col}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Price and Area Distributoins

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['PRICE_CLEANED'], bins=50, kde=True)
plt.title("Distribution of Property Price (₹)")
plt.xscale('log')
plt.xlabel("Price (Log Scale)")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['AREA_CLEANED'], bins=50, kde=True)
plt.title("Distribution of Area (sq.ft.)")
plt.xscale('log')
plt.xlabel("Area (Log Scale)")
plt.show()

# %% [markdown]
# ## Price per Sq.Ft by City Locality

# %%
plt.figure(figsize=(12, 6))
top_cities = df['CITY'].value_counts().nlargest(10).index
sns.boxplot(data=df[df['CITY'].isin(top_cities)], x='CITY', y='PRICE_PER_SQFT')
plt.xticks(rotation=45)
plt.title("Price per Sq.Ft Distribution Across Top 10 Mumbai Localities")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Impact of Bedrooms on Price per Sq. Ft.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df["BEDROOM_NUM"].astype("category"), y=df["PRICE_PER_SQFT"])
plt.title("Price per Sq.Ft by Bedroom Count")
plt.xlabel("Number of Bedrooms")
plt.ylabel("Price per Sq.Ft")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Outlier Detection (Price per Sq.Ft)

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['PRICE_PER_SQFT'])
plt.title("Outlier Check: PRICE_PER_SQFT")
plt.show()

# %%
df.to_csv("../data/processed/mumbai_summary_cleaned.csv", index=False)
